# %% [markdown]
# A2: Ejercicios Básicos en Python_Ana Paula Cantú Díaz 1663389, clase: N1-N3

# %%
nombre = input("Ingrese tu nombre: ") #SE LE PIDE QUE INGRESE LE NOMBRE
if nombre == 'Ana' or nombre == 'Juan' or nombre == 'Pedro': #SE LE PROGRAMA QUE SI EL NOMBRE ES ANA, JUAN Y PERDO IMPRIMA NOMBRE NO VALIDO
  print("Nombre no valido")

elif nombre != 'Ana' or nombre != 'Juan' or nombre != 'Pedro': # Y SI EL NOMBRE ES DIFERENTE A LOS ANTERIORES IPRIMA HOLA Y EL NOMBRE 
    print("Hola",nombre)
