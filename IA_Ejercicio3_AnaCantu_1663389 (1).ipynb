# %% [markdown]
# A2: Ejercicios Básicos en Python_Ana Paula Cantú Díaz 1663389, clase: N1-N3

# %%
Marco=["***********","*Hola *","*mundo, *","*Nada *","*en*","*la *","*vida *","*es *","*para *","*ser *","*temido, *","*es*","*para *","*ser *","*comprendido *","*-Madame Curie *","***********"]
for x in Marco: #SE LE COMENTA QUE EL VALOR DE MARCO, SE LE APLICA EL LOOPS 
  print(x) #Y AQUI SE IMPRIME ESE RESULTADO
