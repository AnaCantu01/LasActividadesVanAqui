# %% [markdown]
# A2: Ejercicios Básicos en Python_Ana Paula Cantú Díaz 1663389, clase: N1-N3

# %%
margen=["***********","*Hola *","*mundo, *","*Nada *","*en*","*la *","*vida *","*es *","*para *","*ser *","*temido, *","*es*","*para *","*ser *","*comprendido *","*-Madame Curie *","***********"]
for x in margen:
  print(x)
# Out:
# ***********
# *Hola *
# *mundo, *
# *Nada *
# *en*
# *la *
# *vida *
# *es *
# *para *
# *ser *
# *temido, *
# *es*
# *para *
# *ser *
# *comprendido *
# *-Madame Curie *
# ***********
