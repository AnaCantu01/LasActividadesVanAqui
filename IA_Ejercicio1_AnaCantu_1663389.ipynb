# %% [markdown]
# A2: Ejercicios Básicos en Python_Ana Paula Cantú Díaz 1663389, clase: N1-N3

# %%
nombre = input("Ingrese tu nombre: ")
if nombre == 'Ana' or nombre == 'Juan' or nombre == 'Pedro':
  print("Nombre no valido")

else:
 if nombre != 'Ana' or nombre != 'Juan' or nombre != 'Pedro':
    print("Hola",nombre)
# Out:
# Ingrese tu nombre: ANDREA
# Hola ANDREA
