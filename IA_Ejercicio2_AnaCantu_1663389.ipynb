# %% [markdown]
# A2: Ejercicios Básicos en Python_Ana Paula Cantú Díaz 1663389, clase: N1-N3

# %%
# AQUI SE LE AGREGAN SUS COMANDOS PREDERTERMINADOS PARA LOGRAR QUE INVIERTA LOS VALORES
from operator import invert
valor = []
for x in range(6): #SE LE INGRESA UN LIMITE DE NUMEROS PARA INGRESAR
 print("Dame un valor: ")
 numero = input() #SE ETIQUET COMO NUMERO EL VALOR DE INPUT
 valor.append(numero)
print("Lista invertida: ")
lista = list(reversed(valor)) #SE GENERA LA LISTA EN BASE A LOS VALORES INGRESADOS
print(lista)

# %%
from operator import invert
valor = []
for x in range(2, 30, 3):
  print("Valor: ",x)
  numero = x
valor.append(numero)
print("Lista revertida:")
lista = list(reversed(valor))
print(lista)
